# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_name('efficientnet-b0')

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'  # b5

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=7)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
## 데이타 로드!!
batch_size  = 2
random_seed = 555
random.seed(random_seed)
torch.manual_seed(random_seed)

## make dataset
from torchvision import transforms, datasets
data_path = 'emotion3/'  # class 별 폴더로 나누어진걸 확 가져와서 라벨도 달아준다
president_dataset = datasets.ImageFolder(
                                data_path,
                                transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))
## data split
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
train_idx, tmp_idx = train_test_split(list(range(len(president_dataset))), test_size=0.2, random_state=random_seed)
datasets = {}
datasets['train'] = Subset(president_dataset, train_idx)
tmp_dataset       = Subset(president_dataset, tmp_idx)

val_idx, test_idx = train_test_split(list(range(len(tmp_dataset))), test_size=0.5, random_state=random_seed)
datasets['valid'] = Subset(tmp_dataset, val_idx)
datasets['test']  = Subset(tmp_dataset, test_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                              batch_size=batch_size, shuffle=True,
                                              num_workers=4)
dataloaders['valid'] = torch.utils.data.DataLoader(datasets['valid'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=4)
dataloaders['test']  = torch.utils.data.DataLoader(datasets['test'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=4)
batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  tvt : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 2,  tvt : 11484 / 1436 / 1436

# %%
## 데이타 체크
import torchvision
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

num_show_img = 5

class_names = {
    "0": "angry",      
    "1": "disgusted",  
    "2": "fearful",  
    "3": "happy",  
    "4": "neutral",  
    "5": "sad",  
    "6": "surprised"   
}

# train check
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# valid check
inputs, classes = next(iter(dataloaders['valid']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# test check
inputs, classes = next(iter(dataloaders['test']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))
           
            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'Efficient_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu
print(torch.cuda.is_available())
# Out:
# True

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.92 Acc: 21.9
# valid Loss: 1.85 Acc: 25.0
# ==> best model saved - 0 / 25.0
# Epoch 1/99
# ----------
# train Loss: 1.77 Acc: 28.7
# valid Loss: 1.64 Acc: 33.8
# ==> best model saved - 1 / 33.8
# Epoch 2/99
# ----------
# train Loss: 1.66 Acc: 34.4
# valid Loss: 1.63 Acc: 36.0
# ==> best model saved - 2 / 36.0
# Epoch 3/99
# ----------
# train Loss: 1.60 Acc: 36.9
# valid Loss: 1.62 Acc: 39.0
# ==> best model saved - 3 / 39.0
# Epoch 4/99
# ----------
# train Loss: 1.57 Acc: 37.6
# valid Loss: 1.56 Acc: 39.2
# ==> best model saved - 4 / 39.2
# Epoch 5/99
# ----------
# train Loss: 1.56 Acc: 38.3
# valid Loss: 1.53 Acc: 39.8
# ==> best model saved - 5 / 39.8
# Epoch 6/99
# ----------
# train Loss: 1.54 Acc: 39.2
# valid Loss: 1.46 Acc: 42.1
# ==> best model saved - 6 / 42.1
# Epoch 7/99
# ----------
# train Loss: 1.53 Acc: 39.5
# valid Loss: 1.54 Acc: 38.4
# Epoch 8/99
# ----------
# train Loss: 1.53 Acc: 39.5
# valid Loss: 1.55 Acc: 42.0
# Epoch 9/99
# ----------
# train Loss: 1.52 Acc: 39.9
# valid Loss: 1.53 Acc: 39.0
# Epoch 10/99
# ----------
# train Loss: 1.50 Acc: 41.2
# valid Loss: 1.50 Acc: 41.5
# Epoch 11/99
# ----------
# train Loss: 1.49 Acc: 41.8
# valid Loss: 1.57 Acc: 37.7
# Epoch 12/99
# ----------
# train Loss: 1.48 Acc: 42.4
# valid Loss: 1.70 Acc: 35.0
# Epoch 13/99
# ----------
# train Loss: 1.48 Acc: 42.1
# valid Loss: 1.50 Acc: 38.9
# Epoch 14/99
# ----------
# train Loss: 1.47 Acc: 42.6
# valid Loss: 1.41 Acc: 46.2
# ==> best model saved - 14 / 46.2
# Epoch 15/99
# ----------
# train Loss: 1.46 Acc: 42.9
# valid Loss: 2.30 Acc: 25.3
# Epoch 16/99
# ----------
# train Loss: 1.46 Acc: 43.1
# valid Loss: 1.55 Acc: 39.7
# Epoch 17/99
# ----------
# train Loss: 1.45 Acc: 43.6
# valid Loss: 1.61 Acc: 35.3
# Epoch 18/99
# ----------
# train Loss: 1.44 Acc: 44.1
# valid Loss: 1.38 Acc: 45.2
# Epoch 19/99
# ----------
# train Loss: 1.43 Acc: 44.5
# valid Loss: 1.45 Acc: 44.7
# Epoch 20/99
# ----------
# train Loss: 1.42 Acc: 44.8
# valid Loss: 1.39 Acc: 47.6
# ==> best model saved - 20 / 47.6
# Epoch 21/99
# ----------
# train Loss: 1.42 Acc: 45.3
# valid Loss: 1.43 Acc: 44.0
# Epoch 22/99
# ----------
# train Loss: 1.41 Acc: 45.8
# valid Loss: 1.45 Acc: 44.1
# Epoch 23/99
# ----------
# train Loss: 1.40 Acc: 45.7
# valid Loss: 1.38 Acc: 45.0
# Epoch 24/99
# ----------
# train Loss: 1.40 Acc: 45.5
# valid Loss: 1.36 Acc: 49.7
# ==> best model saved - 24 / 49.7
# Epoch 25/99
# ----------
# train Loss: 1.39 Acc: 46.2
# valid Loss: 1.37 Acc: 48.8
# Epoch 26/99
# ----------
# train Loss: 1.39 Acc: 46.5
# valid Loss: 1.40 Acc: 48.8
# Epoch 27/99
# ----------
# train Loss: 1.38 Acc: 46.3
# valid Loss: 1.46 Acc: 45.5
# Epoch 28/99
# ----------
# train Loss: 1.39 Acc: 46.2
# valid Loss: 1.44 Acc: 45.3
# Epoch 29/99
# ----------
# train Loss: 1.38 Acc: 47.1
# valid Loss: 1.41 Acc: 48.6
# Epoch 30/99
# ----------
# train Loss: 1.38 Acc: 46.9
# valid Loss: 1.52 Acc: 44.6
# Epoch 31/99
# ----------
# train Loss: 1.37 Acc: 47.0
# valid Loss: 1.63 Acc: 37.2
# Epoch 32/99
# ----------
# train Loss: 1.38 Acc: 46.5
# valid Loss: 1.47 Acc: 44.7
# Epoch 33/99
# ----------
# train Loss: 1.37 Acc: 46.5
# valid Loss: 1.38 Acc: 47.6
# Epoch 34/99
# ----------
# train Loss: 1.37 Acc: 47.6
# valid Loss: 1.32 Acc: 49.9
# ==> best model saved - 34 / 49.9
# Epoch 35/99
# ----------
# train Loss: 1.35 Acc: 48.0
# valid Loss: 1.45 Acc: 45.9
# Epoch 36/99
# ----------
# train Loss: 1.36 Acc: 48.1
# valid Loss: 1.41 Acc: 47.1
# Epoch 37/99
# ----------
# train Loss: 1.35 Acc: 48.1
# valid Loss: 1.37 Acc: 48.3
# Epoch 38/99
# ----------
# train Loss: 1.34 Acc: 48.4
# valid Loss: 1.36 Acc: 48.2
# Epoch 39/99
# ----------
# train Loss: 1.34 Acc: 48.8
# valid Loss: 1.40 Acc: 48.0
# Epoch 40/99
# ----------
# train Loss: 1.34 Acc: 48.5
# valid Loss: 1.29 Acc: 51.8
# ==> best model saved - 40 / 51.8
# Epoch 41/99
# ----------
# train Loss: 1.33 Acc: 49.2
# valid Loss: 1.39 Acc: 48.4
# Epoch 42/99
# ----------
# train Loss: 1.33 Acc: 48.8
# valid Loss: 1.48 Acc: 45.2
# Epoch 43/99
# ----------
# train Loss: 1.32 Acc: 49.3
# valid Loss: 1.33 Acc: 50.7
# Epoch 44/99
# ----------
# train Loss: 1.32 Acc: 49.2
# valid Loss: 1.40 Acc: 46.5
# Epoch 45/99
# ----------
# train Loss: 1.31 Acc: 49.9
# valid Loss: 1.70 Acc: 40.4
# Epoch 46/99
# ----------
# train Loss: 1.31 Acc: 50.3
# valid Loss: 1.43 Acc: 47.6
# Epoch 47/99
# ----------
# train Loss: 1.31 Acc: 50.1
# valid Loss: 1.39 Acc: 50.1
# Epoch 48/99
# ----------
# train Loss: 1.32 Acc: 50.0
# valid Loss: 1.31 Acc: 49.6
# Epoch 49/99
# ----------
# train Loss: 1.31 Acc: 49.9
# valid Loss: 1.32 Acc: 49.8
# Epoch 50/99
# ----------
# train Loss: 1.30 Acc: 50.4
# valid Loss: 1.39 Acc: 44.9
# Epoch 51/99
# ----------
# train Loss: 1.30 Acc: 50.5
# valid Loss: 1.45 Acc: 44.2
# Epoch 52/99
# ----------
# train Loss: 1.29 Acc: 50.8
# valid Loss: 1.38 Acc: 48.1
# Epoch 53/99
# ----------
# train Loss: 1.28 Acc: 51.2
# valid Loss: 1.30 Acc: 49.8
# Epoch 54/99
# ----------
# train Loss: 1.30 Acc: 50.6
# valid Loss: 1.38 Acc: 47.5
# Epoch 55/99
# ----------
# train Loss: 1.28 Acc: 50.9
# valid Loss: 1.44 Acc: 47.1
# Epoch 56/99
# ----------
# train Loss: 1.28 Acc: 51.2
# valid Loss: 1.37 Acc: 47.1
# Epoch 57/99
# ----------
# train Loss: 1.28 Acc: 51.3
# valid Loss: 1.41 Acc: 49.8
# Epoch 58/99
# ----------
# train Loss: 1.27 Acc: 51.6
# valid Loss: 1.36 Acc: 50.7
# Epoch 59/99
# ----------
# train Loss: 1.27 Acc: 51.8
# valid Loss: 1.30 Acc: 51.9
# ==> best model saved - 59 / 51.9
# Epoch 60/99
# ----------
# train Loss: 1.27 Acc: 51.9
# valid Loss: 1.32 Acc: 49.9
# Epoch 61/99
# ----------
# train Loss: 1.26 Acc: 51.7
# valid Loss: 1.39 Acc: 49.6
# Epoch 62/99
# ----------
# train Loss: 1.26 Acc: 52.1
# valid Loss: 1.29 Acc: 50.5
# Epoch 63/99
# ----------
# train Loss: 1.26 Acc: 52.2
# valid Loss: 1.23 Acc: 52.8
# ==> best model saved - 63 / 52.8
# Epoch 64/99
# ----------
# train Loss: 1.25 Acc: 52.2
# valid Loss: 1.53 Acc: 41.2
# Epoch 65/99
# ----------
# train Loss: 1.25 Acc: 52.8
# valid Loss: 1.29 Acc: 51.4
# Epoch 66/99
# ----------
# train Loss: 1.25 Acc: 52.5
# valid Loss: 1.34 Acc: 49.5
# Epoch 67/99
# ----------
# train Loss: 1.24 Acc: 53.1
# valid Loss: 1.30 Acc: 50.3
# Epoch 68/99
# ----------
# train Loss: 1.24 Acc: 53.4
# valid Loss: 1.31 Acc: 50.7
# Epoch 69/99
# ----------
# train Loss: 1.24 Acc: 52.9
# valid Loss: 1.52 Acc: 47.6
# Epoch 70/99
# ----------
# train Loss: 1.23 Acc: 53.9
# valid Loss: 1.35 Acc: 47.4
# Epoch 71/99
# ----------
# train Loss: 1.23 Acc: 53.1
# valid Loss: 1.21 Acc: 55.3
# ==> best model saved - 71 / 55.3
# Epoch 72/99
# ----------
# train Loss: 1.23 Acc: 54.0
# valid Loss: 1.27 Acc: 51.5
# Epoch 73/99
# ----------
# train Loss: 1.22 Acc: 54.4
# valid Loss: 1.30 Acc: 51.1
# Epoch 74/99
# ----------
# train Loss: 1.21 Acc: 54.2
# valid Loss: 1.42 Acc: 45.6
# Epoch 75/99
# ----------
# train Loss: 1.22 Acc: 54.3
# valid Loss: 1.24 Acc: 52.0
# Epoch 76/99
# ----------
# train Loss: 1.21 Acc: 54.2
# valid Loss: 1.31 Acc: 47.7
# Epoch 77/99
# ----------
# train Loss: 1.21 Acc: 54.3
# valid Loss: 1.31 Acc: 51.1
# Epoch 78/99
# ----------
# train Loss: 1.20 Acc: 55.0
# valid Loss: 1.30 Acc: 50.1
# Epoch 79/99
# ----------
# train Loss: 1.20 Acc: 54.5
# valid Loss: 1.32 Acc: 48.0
# Epoch 80/99
# ----------
# train Loss: 1.19 Acc: 55.2
# valid Loss: 1.28 Acc: 51.3
# Epoch 81/99
# ----------
# train Loss: 1.20 Acc: 54.9
# valid Loss: 1.32 Acc: 51.8
# Epoch 82/99
# ----------
# train Loss: 1.19 Acc: 54.7
# valid Loss: 1.22 Acc: 55.1
# Epoch 83/99
# ----------
# train Loss: 1.19 Acc: 55.0
# valid Loss: 1.43 Acc: 45.1
# Epoch 84/99
# ----------
# train Loss: 1.19 Acc: 55.1
# valid Loss: 1.24 Acc: 52.9
# Epoch 85/99
# ----------
# train Loss: 1.18 Acc: 55.2
# valid Loss: 1.25 Acc: 54.6
# Epoch 86/99
# ----------
# train Loss: 1.18 Acc: 55.7
# valid Loss: 1.21 Acc: 54.8
# Epoch 87/99
# ----------
# train Loss: 1.18 Acc: 55.5
# valid Loss: 1.29 Acc: 52.9
# Epoch 88/99
# ----------
# train Loss: 1.18 Acc: 55.5
# valid Loss: 1.26 Acc: 52.2
# Epoch 89/99
# ----------
# train Loss: 1.17 Acc: 55.8
# valid Loss: 1.23 Acc: 54.4
# Epoch 90/99
# ----------
# train Loss: 1.17 Acc: 56.3
# valid Loss: 1.25 Acc: 52.5
# Epoch 91/99
# ----------
# train Loss: 1.17 Acc: 56.0
# valid Loss: 1.20 Acc: 54.5
# Epoch 92/99
# ----------
# train Loss: 1.17 Acc: 56.1
# valid Loss: 1.24 Acc: 53.9
# Epoch 93/99
# ----------
# train Loss: 1.16 Acc: 56.4
# valid Loss: 1.31 Acc: 51.1
# Epoch 94/99
# ----------
# train Loss: 1.16 Acc: 56.3
# valid Loss: 1.41 Acc: 44.4
# Epoch 95/99
# ----------
# train Loss: 1.15 Acc: 57.0
# valid Loss: 1.26 Acc: 52.5
# Epoch 96/99
# ----------
# train Loss: 1.15 Acc: 57.0
# valid Loss: 1.22 Acc: 53.6
# Epoch 97/99
# ----------
# train Loss: 1.14 Acc: 56.9
# valid Loss: 1.25 Acc: 51.9
# Epoch 98/99
# ----------
# train Loss: 1.14 Acc: 56.8
# valid Loss: 1.24 Acc: 53.9
# Epoch 99/99
# ----------
# train Loss: 1.14 Acc: 57.2
# valid Loss: 1.24 Acc: 54.4
# Training complete in 886m 10s
# Best valid Acc: 71 - 55.3
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 71 - 55 / 1.2

# %%
def test_and_visualize_model(model, phase = 'test', num_images=4):
    # phase = 'train', 'valid', 'test'
    
    was_training = model.training
    model.eval()
    fig = plt.figure()
    
    running_loss, running_corrects, num_cnt = 0.0, 0, 0

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)  # batch의 평균 loss 출력

            running_loss    += loss.item() * inputs.size(0)
            running_corrects+= torch.sum(preds == labels.data)
            num_cnt += inputs.size(0)  # batch size

    #         if i == 2: break

        test_loss = running_loss / num_cnt
        test_acc  = running_corrects.double() / num_cnt       
        print('test done : loss/acc : %.2f / %.1f' % (test_loss, test_acc*100))

    # 예시 그림 plot
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)        

            # 예시 그림 plot
            for j in range(1, num_images+1):
                ax = plt.subplot(num_images//2, 2, j)
                ax.axis('off')
                ax.set_title('%s : %s -> %s'%(
                    'True' if class_names[str(labels[j].cpu().numpy())]==class_names[str(preds[j].cpu().numpy())] else 'False',
                    class_names[str(labels[j].cpu().numpy())], class_names[str(preds[j].cpu().numpy())]))
                imshow(inputs.cpu().data[j])          
            if i == 0 : break


    model.train(mode=was_training);  # 다시 train모드로
    
    ## TEST!
    test_and_visualize_model(model, phase = 'test')
