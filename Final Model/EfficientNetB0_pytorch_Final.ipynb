# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_name('efficientnet-b0')

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'  # b5

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
## 데이타 로드!!
batch_size  = 16
random_seed = 555
random.seed(random_seed)
torch.manual_seed(random_seed)

## make dataset
from torchvision import transforms, datasets
data_path = 'emotion_FixedVer/'  # class 별 폴더로 나누어진걸 확 가져와서 라벨도 달아준다
emotion_dataset = datasets.ImageFolder(
                                data_path,
                                transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))
## data split
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
train_idx, tmp_idx = train_test_split(list(range(len(emotion_dataset))), test_size=0.2, random_state=random_seed)
datasets = {}
datasets['train'] = Subset(emotion_dataset, train_idx)
tmp_dataset       = Subset(emotion_dataset, tmp_idx)

val_idx, test_idx = train_test_split(list(range(len(tmp_dataset))), test_size=0.5, random_state=random_seed)
datasets['valid'] = Subset(tmp_dataset, val_idx)
datasets['test']  = Subset(tmp_dataset, test_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                              batch_size=batch_size, shuffle=True,
                                              num_workers=4)
dataloaders['valid'] = torch.utils.data.DataLoader(datasets['valid'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=4)
dataloaders['test']  = torch.utils.data.DataLoader(datasets['test'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=4)
batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  tvt : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 16,  tvt : 1394 / 175 / 175

# %%
## 데이타 체크
import torchvision
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

num_show_img = 5

class_names = {
    "0": "angry",      
    "1": "fearful",  
    "2": "happy",  
    "3": "neutral",  
    "4": "sad",  
    "5": "surprised"
}

# train check
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# valid check
inputs, classes = next(iter(dataloaders['valid']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# test check
inputs, classes = next(iter(dataloaders['test']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))
           
            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'EfficientNetb5_pytorch_6emotion.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu
print(torch.cuda.is_available())
# Out:
# True

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.001,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
batch_size  = 32

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.42 Acc: 43.9
# valid Loss: 1.27 Acc: 50.4
# ==> best model saved - 0 / 50.4
# Epoch 1/99
# ----------
# train Loss: 1.13 Acc: 56.3
# valid Loss: 1.06 Acc: 59.2
# ==> best model saved - 1 / 59.2
# Epoch 2/99
# ----------
# train Loss: 1.01 Acc: 61.3
# valid Loss: 1.06 Acc: 60.2
# ==> best model saved - 2 / 60.2
# Epoch 3/99
# ----------
# train Loss: 0.92 Acc: 64.8
# valid Loss: 1.02 Acc: 61.2
# ==> best model saved - 3 / 61.2
# Epoch 4/99
# ----------
# train Loss: 0.85 Acc: 68.1
# valid Loss: 0.96 Acc: 64.4
# ==> best model saved - 4 / 64.4
# Epoch 5/99
# ----------
# train Loss: 0.78 Acc: 70.8
# valid Loss: 0.95 Acc: 65.1
# ==> best model saved - 5 / 65.1
# Epoch 6/99
# ----------
# train Loss: 0.71 Acc: 73.6
# valid Loss: 0.94 Acc: 66.1
# ==> best model saved - 6 / 66.1
# Epoch 7/99
# ----------
# train Loss: 0.64 Acc: 76.3
# valid Loss: 1.01 Acc: 64.5
# Epoch 8/99
# ----------
# train Loss: 0.58 Acc: 78.6
# valid Loss: 1.01 Acc: 66.4
# ==> best model saved - 8 / 66.4
# Epoch 9/99
# ----------
# train Loss: 0.50 Acc: 81.8
# valid Loss: 1.04 Acc: 65.3
# Epoch 10/99
# ----------
# train Loss: 0.44 Acc: 84.1
# valid Loss: 1.17 Acc: 65.0
# Epoch 11/99
# ----------
# train Loss: 0.39 Acc: 85.9
# valid Loss: 1.17 Acc: 66.2
# Epoch 12/99
# ----------
# train Loss: 0.34 Acc: 88.0
# valid Loss: 1.25 Acc: 63.0
# Epoch 13/99
# ----------
# train Loss: 0.30 Acc: 89.4
# valid Loss: 1.27 Acc: 64.9
# Epoch 14/99
# ----------
# train Loss: 0.26 Acc: 91.0
# valid Loss: 1.32 Acc: 66.5
# ==> best model saved - 14 / 66.5
# Epoch 15/99
# ----------
# train Loss: 0.23 Acc: 92.1
# valid Loss: 1.34 Acc: 66.9
# ==> best model saved - 15 / 66.9
# Epoch 16/99
# ----------
# train Loss: 0.21 Acc: 93.0
# valid Loss: 1.44 Acc: 66.0
# Epoch 17/99
# ----------
# train Loss: 0.18 Acc: 93.8
# valid Loss: 1.45 Acc: 65.5
# Epoch 18/99
# ----------
# train Loss: 0.17 Acc: 94.4
# valid Loss: 1.41 Acc: 66.4
# Epoch 19/99
# ----------
# train Loss: 0.16 Acc: 94.6
# valid Loss: 1.53 Acc: 66.2
# Epoch 20/99
# ----------
# train Loss: 0.14 Acc: 95.3
# valid Loss: 1.57 Acc: 65.1
# Epoch 21/99
# ----------
# train Loss: 0.13 Acc: 95.7
# valid Loss: 1.55 Acc: 65.9
# Epoch 22/99
# ----------
# train Loss: 0.12 Acc: 96.1
# valid Loss: 1.57 Acc: 66.7
# Epoch 23/99
# ----------
# train Loss: 0.11 Acc: 96.2
# valid Loss: 1.57 Acc: 67.3
# ==> best model saved - 23 / 67.3
# Epoch 24/99
# ----------
# train Loss: 0.10 Acc: 96.7
# valid Loss: 1.59 Acc: 66.7
# Epoch 25/99
# ----------
# train Loss: 0.10 Acc: 96.6
# valid Loss: 1.61 Acc: 66.9
# Epoch 26/99
# ----------
# train Loss: 0.09 Acc: 97.0
# valid Loss: 1.66 Acc: 66.8
# Epoch 27/99
# ----------
# train Loss: 0.09 Acc: 97.2
# valid Loss: 1.64 Acc: 67.0
# Epoch 28/99
# ----------
# train Loss: 0.08 Acc: 97.3
# valid Loss: 1.65 Acc: 66.9
# Epoch 29/99
# ----------
# train Loss: 0.08 Acc: 97.4
# valid Loss: 1.66 Acc: 66.8
# Epoch 30/99
# ----------
# train Loss: 0.08 Acc: 97.6
# valid Loss: 1.65 Acc: 66.4
# Epoch 31/99
# ----------
# train Loss: 0.07 Acc: 97.8
# valid Loss: 1.69 Acc: 67.0
# Epoch 32/99
# ----------
# train Loss: 0.07 Acc: 97.9
# valid Loss: 1.69 Acc: 67.4
# ==> best model saved - 32 / 67.4
# Epoch 33/99
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 1.73 Acc: 66.8
# Epoch 34/99
# ----------
# train Loss: 0.06 Acc: 98.0
# valid Loss: 1.71 Acc: 67.4
# Epoch 35/99
# ----------
# train Loss: 0.06 Acc: 98.2
# valid Loss: 1.79 Acc: 67.4
# Epoch 36/99
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.76 Acc: 66.9
# Epoch 37/99
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.78 Acc: 66.6
# Epoch 38/99
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.77 Acc: 67.2
# Epoch 39/99
# ----------
# train Loss: 0.05 Acc: 98.2
# valid Loss: 1.79 Acc: 67.6
# ==> best model saved - 39 / 67.6
# Epoch 40/99
# ----------
# train Loss: 0.05 Acc: 98.3
# valid Loss: 1.74 Acc: 68.1
# ==> best model saved - 40 / 68.1
# Epoch 41/99
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.79 Acc: 66.9
# Epoch 42/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 1.81 Acc: 66.7
# Epoch 43/99
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.83 Acc: 67.7
# Epoch 44/99
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.84 Acc: 67.1
# Epoch 45/99
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.88 Acc: 67.6
# Epoch 46/99
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.85 Acc: 67.5
# Epoch 47/99
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.80 Acc: 67.6
# Epoch 48/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.88 Acc: 67.5
# Epoch 49/99
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.86 Acc: 68.4
# ==> best model saved - 49 / 68.4
# Epoch 50/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.84 Acc: 67.9
# Epoch 51/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.90 Acc: 68.1
# Epoch 52/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.86 Acc: 66.1
# Epoch 53/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.88 Acc: 67.0
# Epoch 54/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.88 Acc: 67.1
# Epoch 55/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.91 Acc: 67.5
# Epoch 56/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.90 Acc: 66.8
# Epoch 57/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.91 Acc: 67.7
# Epoch 58/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 1.90 Acc: 67.6
# Epoch 59/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.86 Acc: 66.9
# Epoch 60/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.89 Acc: 67.0
# Epoch 61/99
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.92 Acc: 67.6
# Epoch 62/99
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.94 Acc: 67.9
# Epoch 63/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.94 Acc: 67.5
# Epoch 64/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.94 Acc: 67.5
# Epoch 65/99
# ----------
# train Loss: 0.03 Acc: 99.2
# valid Loss: 1.94 Acc: 67.6
# Epoch 66/99
# ----------
# train Loss: 0.03 Acc: 99.2
# valid Loss: 1.99 Acc: 67.4
# Epoch 67/99
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.95 Acc: 67.3
# Epoch 68/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.97 Acc: 66.9
# Epoch 69/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.96 Acc: 67.5
# Epoch 70/99
# ----------
# train Loss: 0.03 Acc: 99.2
# valid Loss: 1.95 Acc: 67.9
# Epoch 71/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.95 Acc: 67.5
# Epoch 72/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.98 Acc: 67.5
# Epoch 73/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.98 Acc: 68.0
# Epoch 74/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.97 Acc: 67.6
# Epoch 75/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.96 Acc: 67.3
# Epoch 76/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.99 Acc: 67.3
# Epoch 77/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 2.00 Acc: 67.0
# Epoch 78/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.95 Acc: 67.2
# Epoch 79/99
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 2.01 Acc: 67.2
# Epoch 80/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 2.00 Acc: 67.7
# Epoch 81/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 2.02 Acc: 67.7
# Epoch 82/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.98 Acc: 67.7
# Epoch 83/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 2.00 Acc: 67.9
# Epoch 84/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.97 Acc: 67.4
# Epoch 85/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 1.98 Acc: 67.5
# Epoch 86/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.00 Acc: 67.2
# Epoch 87/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.01 Acc: 67.7
# Epoch 88/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.05 Acc: 67.0
# Epoch 89/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.00 Acc: 67.1
# Epoch 90/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.05 Acc: 67.2
# Epoch 91/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 2.03 Acc: 67.9
# Epoch 92/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.02 Acc: 67.5
# Epoch 93/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.03 Acc: 67.1
# Epoch 94/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 2.01 Acc: 66.9
# Epoch 95/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.99 Acc: 67.2
# Epoch 96/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.03 Acc: 67.6
# Epoch 97/99
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 2.01 Acc: 67.1
# Epoch 98/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 2.00 Acc: 67.1
# Epoch 99/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 2.01 Acc: 67.6
# Training complete in 314m 10s
# Best valid Acc: 49 - 68.4
# model saved

# %%
print(best_acc)
# Out:
# 68.38894869034804

# %%
for i in range(len(train_acc)):
    train_acc[i] = train_acc[i] / 100
for i in range(len(valid_acc)):
    valid_acc[i] = valid_acc[i] / 100

# %%
fig = plt.title("model accuracy")
plt.plot(train_acc)
plt.plot(valid_acc)
plt.axis([1, 100, 0, 1])
plt.ylabel("accuracy", fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("epoch", fontsize=15)
plt.legend(["train", "validation"], loc="lower right")
plt.show()
